# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sqlalchemy import text

# %%
url1 = r"C:\Users\admin\Documents\GitHub\projects\Vanguard_project\datafiles\df_final_demo.txt"
df_final_demo = pd.read_csv(url1)
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
url2 = r"C:\Users\admin\Documents\GitHub\projects\Vanguard_project\datafiles\df_final_web_data_pt_1.txt"
df_final_web_data_pt_1 = pd.read_csv(url2)
df_final_web_data_pt_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
url3 = r"C:\Users\admin\Documents\GitHub\projects\Vanguard_project\datafiles\df_final_web_data_pt_2.txt"
df_final_web_data_pt_2 = pd.read_csv(url3)
df_final_web_data_pt_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
# Merge final web data part 1 and 2
df_final_web_data = pd.concat([df_final_web_data_pt_1, df_final_web_data_pt_2], axis=0, join='outer', ignore_index=True)
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
url4 = r"C:\Users\admin\Documents\GitHub\projects\Vanguard_project\datafiles\df_final_experiment_clients.txt"
df_final_experiment_clients = pd.read_csv(url4)
df_final_experiment_clients
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
# Timo: Cleaning df_final_demo dataframe
df_final_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB

# %%
# Null values checking
df_final_demo.isnull().any()
# Out:
# client_id           False
# clnt_tenure_yr       True
# clnt_tenure_mnth     True
# clnt_age             True
# gendr                True
# num_accts            True
# bal                  True
# calls_6_mnth         True
# logons_6_mnth        True
# dtype: bool

# %%
# Null values checking
df_final_demo.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
# Null values dropping
df_final_demo_clean = df_final_demo.dropna()
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
# duplicates checking
df_final_demo_clean.duplicated().any()
# Out:
# False

# %%
df_final_demo_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70594 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70594 non-null  int64
#  1   clnt_tenure_yr    70594 non-null  float64
#  2   clnt_tenure_mnth  70594 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70594 non-null  object
#  5   num_accts         70594 non-null  float64
#  6   bal               70594 non-null  float64
#  7   calls_6_mnth      70594 non-null  float64
#  8   logons_6_mnth     70594 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 5.4+ MB

# %%
# Data Type formatting: floats --> integers
df_final_demo_clean["clnt_tenure_yr"] = df_final_demo_clean["clnt_tenure_yr"].astype(int)
df_final_demo_clean["clnt_tenure_mnth"] = df_final_demo_clean["clnt_tenure_mnth"].astype(int)
df_final_demo_clean["num_accts"] = df_final_demo_clean["num_accts"].astype(int)
df_final_demo_clean["calls_6_mnth"] = df_final_demo_clean["calls_6_mnth"].astype(int)
df_final_demo_clean["logons_6_mnth"] = df_final_demo_clean["logons_6_mnth"].astype(int)
df_final_demo_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70594 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70594 non-null  int64
#  1   clnt_tenure_yr    70594 non-null  int32
#  2   clnt_tenure_mnth  70594 non-null  int32
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70594 non-null  object
#  5   num_accts         70594 non-null  int32
#  6   bal               70594 non-null  float64
#  7   calls_6_mnth      70594 non-null  int32
#  8   logons_6_mnth     70594 non-null  int32
# dtypes: float64(2), int32(5), int64(1), object(1)
# memory usage: 4.0+ MB
# C:\Users\admin\AppData\Local\Temp\ipykernel_20576\4198727276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976               6                73      60.5     U          2
# 1        2304905               7                94      58.0     U          2
# 2        1439522               5                64      32.0     U          2
# 3        1562045              16               198      49.0     M          2
# 4        5126305              12               145      33.0     F          2
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686               4                56      38.5     U          3
# 70605    8981690              12               148      31.0     M          2
# 70606     333913              16               198      61.5     F          2
# 70607    1573142              21               255      68.0     M          3
# 70608    5602139              21               254      59.5     F          3
#
# ...

# %%
# Check Gender Column
df_final_demo_clean["gendr"].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22745
# X        3
# Name: count, dtype: int64

# %%
df_final_demo_clean.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.059400e+04    70594.000000      70594.000000  70594.000000
# mean   5.005026e+06       12.053007        150.659999     46.442240
# std    2.877289e+06        6.871850         82.090264     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519543e+06        6.000000         82.000000     32.500000
# 50%    5.016974e+06       11.000000        136.000000     47.000000
# 75%    7.483074e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70594.000000  7.059400e+04  70594.000000   70594.000000
# mean       2.255532  1.474467e+05      3.382469       5.566720
# std        0.535000  3.015106e+05      2.236595       2.353296
# min        1.000000  1.378942e+04      0.000000       1.000000
# ...

# %%
# bal column rounding
df_final_demo_clean['bal'] = df_final_demo_clean['bal'].round(2)
df_final_demo_clean.describe()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20576\229035803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_demo_clean['bal'] = df_final_demo_clean['bal'].round(2)
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.059400e+04    70594.000000      70594.000000  70594.000000
# mean   5.005026e+06       12.053007        150.659999     46.442240
# std    2.877289e+06        6.871850         82.090264     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519543e+06        6.000000         82.000000     32.500000
# 50%    5.016974e+06       11.000000        136.000000     47.000000
# 75%    7.483074e+06       16.000000        192.000000     59.000000
# ...

# %%
# Creating histograms for each numerical column in 'df_final_demo_clean'
df_final_demo_clean.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);
plt.show()

# %%
# Safe cleaned dataframe "df_final_demo_clean":
df_final_demo_clean.to_csv('df_final_demo_clean.csv', index=False) # This shall only be done once !

# %%
# Timo: Cleaning dataframe: df_final_experiment_clients
df_final_experiment_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  50500 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB

# %%
# Null values checking
df_final_experiment_clients.isnull().any()
# Out:
# client_id    False
# Variation     True
# dtype: bool

# %%
# Null values checking --> 20109 of the 70609 clients were neither test nor control group !
df_final_experiment_clients.isnull().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
# Check values in Variation column
df_final_experiment_clients["Variation"].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
# duplicates checking
df_final_experiment_clients.duplicated().any()
# Out:
# False

# %%
# Safe cleaned dataframe "df_final_experiment_clients" (there was no cleaning necessary):
df_final_experiment_clients.to_csv('df_final_experiment_clients.csv', index=False) # This shall only be done once !

# %%
# Check Gender Column
df_final_demo_clean["gendr"].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22745
# X        3
# Name: count, dtype: int64

# %%
# Gender Distribution plotted
sns.countplot(data=df_final_demo_clean, x='gendr', palette="coolwarm");
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender demographics of Vanguard clients")

# Safe the plot (needs to be done first, before showing it!)
plt.savefig("Vanguard_clients_gender.png", dpi=300)
####  ONLY RUN ONCE !!!! ####

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20576\463417015.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_final_demo_clean, x='gendr', palette="coolwarm");
